# %%
import numpy as np
import pandas as pd
import ts2vg
import h5py
import os

# %%
df: pd.DataFrame = pd.read_csv("data/exams_labels_filtered.csv")
display(df.shape)
df
# Out:
# (34104, 16)
#        exam_id  age  is_male  nn_predicted_age  1dAVb   RBBB   LBBB     SB  \
# 0       168405   67     True         79.621740  False  False  False  False
# 1       132538   85    False         87.512890  False  False  False  False
# 2       552294   79     True         79.434006  False  False  False   True
# 3       605089   75     True         75.876625  False   True  False  False
# 4      2821208   43    False         82.751550  False  False  False  False
# ...        ...  ...      ...               ...    ...    ...    ...    ...
# 34099  3140838   59    False         60.489555  False  False  False  False
# 34100   739700   66     True         62.225470   True  False  False  False
# 34101   844597   60    False         67.015120  False  False   True  False
# 34102  1066754   26    False         20.644780  False  False  False  False
# 34103  1516436   62     True         69.624886  False   True  False  False
#
# ...

# %%
filtered_ids = df.exam_id
filtered_ids
# Out:
# 0         168405
# 1         132538
# 2         552294
# 3         605089
# 4        2821208
#           ...
# 34099    3140838
# 34100     739700
# 34101     844597
# 34102    1066754
# 34103    1516436
# Name: exam_id, Length: 34104, dtype: int64

# %%
for f in os.listdir("exams"):
    with h5py.File(f, "r") as exam_file:
        pass
